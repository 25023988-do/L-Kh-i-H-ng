# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input('nhập vào số nguyên n:'))
print(n * 2)
# Out:
# 4

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
a = float(input('Nhập chiều rộng a:'))
b = float(input('nhập chiều rộng b:'))
pi = 3.14
r = a / 2
s_hcn = a * b
s_ht = pi * (r ** 2)
s_trongcay = s_hcn - s_ht
print(f'{s_trongcay:.2f}')
# Out:
# 4.93

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input('nhập vào một kí tự c:')
if c.isupper():
    print(c.lower())
elif c.islower():
    print(c.upper())
else:
    print(c)
# Out:
# &

# %% [markdown]
# Bài 5: NBài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet. hập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input('nhập vào 1 kí tự c:')
if c.isalpha():
    print('c là kí tự alphabet')
else: 
    print('c không phải là kí tự alphabet')
# Out:
# c không phải là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
A = input('nhập vào chữ cái hoa A:')
if A == "A":
    print('z')
else:
    chu_thuong = A.lower()
    lien_truoc = chr(ord(chu_thuong) - 1)
    print(lien_truoc)
# Out:
# b

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math
a = float(input('nhập số a:'))
b = float(input('nhập số b:'))
c = float(input('nhập số c:'))
if a + b > c and b + c > a and a + c > b:
    p = (a  + b + c) / 2
    s = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print('diện tích tam giác là ' f'{s:.1f}')
else: 
    print('đây không phải là tam giac')
# Out:
# đây không phải là tam giac

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
c = input('nhập chuỗi kí tự thường độ dài >=20:')
if len(c) >= 20:
    print('chữ cái thứ 5:',c[4])
    print('chữ cái thứ 9:',c[8])
else:
    print('không đủ độ dài')
# Out:
# chữ cái thứ 5: n
# chữ cái thứ 9: c

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ biết:
# -	Từ 0 – 50kWh: 1.984 đồng/kWh
# -	Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# -	Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# -	Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# -	Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# -	Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
#
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng
# Input 	Ouput
# Ten chu ho: Pham Xuan Toai
# Chi so thang truoc: 1020
# Chi so thang nay: 1070
#  	Ho va ten: Pham Xuan Toai
# Tien phai tra la: 107136
# Ten chu ho: Nguyen Xuan Long
# Chi so thang truoc: 2097
# Chi so thang nay: 2278 	Ho va ten: Nguyen Xuan Long
# Tien phai tra la: 426038
#
# Ten chu ho: Nguyen Xuan Hai
# Chi so thang truoc: 2000
# Chi so thang nay: 2586
#  	Ho va ten: Nguyen Xuan Hai
# Tien phai tra la: 1855505

# %%
a = input('họ tên chủ hộ: ')
b = float(input('số điện tháng trước: '))
c = float(input('số điện tháng này: '))
so_dien= c - b
tien_truoc_vat = 0
if so_dien <= 50:
    tien_truoc_vat = so_dien * 1984
elif so_dien <=100:
    tien_truoc_vat = 50 * 1984 + (so_dien - 50) * 2050
elif so_dien <=200:
    tien_truoc_vat = 50 * 1984 + 50 * 2050 + (so_dien - 100) * 2380
elif so_dien <=300:
    tien_truoc_vat = 50 * 1984 + 50 * 2050 + 100 * 2380 + (so_dien - 200) * 2998
elif so_dien <=400:
    tien_truoc_vat = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (so_dien - 300) * 3350
else:
    tien_truoc_vat = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (so_dien - 400) * 3460
tien_sau_vat = tien_truoc_vat * 1.08
so_tien = round(tien_sau_vat)
print('ho ten chu ho:',a)
print('so tien phai tra:',so_tien)
# Out:
# ho ten chu ho: lo khai hung
# so tien phai tra: 3402540
